# %%
# Loading the Packages
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the dataset
data = pd.read_csv("C:/Users/USER/VIT/dataset.csv")
data
# Out:
#          ID Region of residence  Age of Subject  Time spent on Online Class  \
# 0        R1           Delhi-NCR              21                         2.0
# 1        R2           Delhi-NCR              21                         0.0
# 2        R3           Delhi-NCR              20                         7.0
# 3        R4           Delhi-NCR              20                         3.0
# 4        R5           Delhi-NCR              21                         3.0
# ...     ...                 ...             ...                         ...
# 1177  R1191           Delhi-NCR              12                         3.0
# 1178  R1192           Delhi-NCR              14                         6.0
# 1179  R1193           Delhi-NCR              13                         4.0
# 1180  R1194           Delhi-NCR              14                         5.0
# 1181  R1195           Delhi-NCR              13                         5.0
#
# ...

# %%
# Shape of the data
print('Shape of the data',data.shape)
# Out:
# Shape of the data (1182, 19)

# %%
# statistical tools
data.describe()
# Out:
#        Age of Subject  Time spent on Online Class  Time spent on self study  \
# count     1182.000000                 1182.000000               1182.000000
# mean        20.165821                    3.208841                  2.911591
# std          5.516467                    2.101756                  2.140590
# min          7.000000                    0.000000                  0.000000
# 25%         17.000000                    2.000000                  2.000000
# 50%         20.000000                    3.000000                  2.000000
# 75%         21.000000                    5.000000                  4.000000
# max         59.000000                   10.000000                 18.000000
#
#        Time spent on fitness  Time spent on sleep  Time spent on social media  \
# count            1182.000000          1182.000000                 1182.000000
# mean                0.765821             7.871235                    2.365694
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Region of residence', 'Age of Subject',
#        'Time spent on Online Class', 'Rating of Online Class experience',
#        'Medium for online class', 'Time spent on self study',
#        'Time spent on fitness', 'Time spent on sleep',
#        'Time spent on social media', 'Prefered social media platform',
#        'Time spent on TV', 'Number of meals per day', 'Change in your weight',
#        'Health issue during lockdown', 'Stress busters', 'Time utilized',
#        'Do you find yourself more connected with your family, close friends , relatives  ?',
#        'What you miss the most'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# ID                                                                                     0
# Region of residence                                                                    0
# Age of Subject                                                                         0
# Time spent on Online Class                                                             0
# Rating of Online Class experience                                                     24
# Medium for online class                                                               51
# Time spent on self study                                                               0
# Time spent on fitness                                                                  0
# Time spent on sleep                                                                    0
# Time spent on social media                                                             0
# ...

# %%
data1 = data.dropna()
data1
# Out:
#          ID Region of residence  Age of Subject  Time spent on Online Class  \
# 0        R1           Delhi-NCR              21                         2.0
# 1        R2           Delhi-NCR              21                         0.0
# 2        R3           Delhi-NCR              20                         7.0
# 3        R4           Delhi-NCR              20                         3.0
# 4        R5           Delhi-NCR              21                         3.0
# ...     ...                 ...             ...                         ...
# 1177  R1191           Delhi-NCR              12                         3.0
# 1178  R1192           Delhi-NCR              14                         6.0
# 1179  R1193           Delhi-NCR              13                         4.0
# 1180  R1194           Delhi-NCR              14                         5.0
# 1181  R1195           Delhi-NCR              13                         5.0
#
# ...

# %%
data1.isnull().sum()
# Out:
# ID                                                                                    0
# Region of residence                                                                   0
# Age of Subject                                                                        0
# Time spent on Online Class                                                            0
# Rating of Online Class experience                                                     0
# Medium for online class                                                               0
# Time spent on self study                                                              0
# Time spent on fitness                                                                 0
# Time spent on sleep                                                                   0
# Time spent on social media                                                            0
# Prefered social media platform                                                        0
# ...

# %%
print(data1['Region of residence'].unique())
print(data1['Rating of Online Class experience'].unique())
print(data1['Medium for online class'].unique())
print(data1['Prefered social media platform'].unique())
print(data1['Change in your weight'].unique())
print(data1['Health issue during lockdown'].unique())
print(data1['Time utilized'].unique())
print(data1['Do you find yourself more connected with your family, close friends , relatives  ?'].unique())
# Out:
# ['Delhi-NCR' 'Outside Delhi-NCR']
# ['Good' 'Excellent' 'Very poor' 'Average' 'Poor']
# ['Laptop/Desktop' 'Smartphone' 'Tablet' 'Any Gadget'
#  'Smartphone or Laptop/Desktop']
# ['Linkedin' 'Youtube' 'Instagram' 'Whatsapp' 'None' 'Reddit' 'Snapchat'
#  'Twitter' 'Telegram' 'Facebook' 'Elyment' 'None ' 'Quora' 'Talklife'
#  'WhatsApp']
# ['Increased' 'Decreased' 'Remain Constant']
# ['NO' 'YES']
# ['YES' 'NO']
# ['YES' 'NO']

# %%
data1.nunique()
# Out:
# ID                                                                                    1131
# Region of residence                                                                      2
# Age of Subject                                                                          42
# Time spent on Online Class                                                              20
# Rating of Online Class experience                                                        5
# Medium for online class                                                                  5
# Time spent on self study                                                                23
# Time spent on fitness                                                                   11
# Time spent on sleep                                                                     18
# Time spent on social media                                                              22
# ...

# %%
data['Time spent on TV'].replace('No tv', 0, inplace=True)
data['Time spent on TV'].replace('n', 0, inplace=True)
data['Time spent on TV'].replace('N', 0, inplace=True)
data['Time spent on TV'].replace(' ', 0, inplace=True)
data['Time spent on TV'] = data['Time spent on TV'].astype('float')
data['Prefered social media platform'] = data['Prefered social media platform'].replace('None ', 'None')
data['Prefered social media platform'] = data['Prefered social media platform'].replace('Whatsapp', 'WhatsApp')
data.rename(columns = {"Health issue during lockdown":"Mental Health issue during lockdown"}, inplace = True)

# %%
plt.figure(figsize=(20,10))
sns.displot(data1['Age of Subject'])
plt.title('Distribution of Age Subject')
plt.show()

# %%
medium_val = data['Medium for online class'].value_counts().to_dict()
medium_val
# Out:
# {'Laptop/Desktop': 545,
#  'Smartphone': 539,
#  'Tablet': 37,
#  'Any Gadget': 5,
#  'Smartphone or Laptop/Desktop': 5}

# %%
plt.figure(figsize=(12,8))
sns.set(style='ticks')
sns.countplot(y='Medium for online class', data=data1, 
              order=data1['Medium for online class'].value_counts().index[:5], palette='Set2')
plt.xlabel("Number of Students", weight='bold')
plt.ylabel("Medium of online class", weight='bold')
plt.show()

# %%
dict_ = data['Prefered social media platform'].value_counts().to_dict()
plt.figure(figsize=(14,14))
plt.pie(x=dict_.values(),autopct='%1.1f%%', startangle=90,radius=0.75)
plt.legend(labels=dict_.keys(), loc='upper right',shadow=True, facecolor='lightyellow')
plt.show()

# %%
# How they utilised their time?
plt.figure(figsize=(14,10))
sns.set(style='whitegrid')
sns.boxplot(data=data[['Time spent on Online Class','Time spent on self study','Time spent on fitness',
                       'Time spent on sleep','Time spent on social media', 'Time spent on TV']], orient='h', palette='Set3')
plt.show()

# %%
sns.set(style='darkgrid')
fig, ax = plt.subplots(2,2, figsize=(16,18))
sns.violinplot(x='Mental Health issue during lockdown', y='Time spent on Online Class', data=data, ax=ax[0,0])
sns.violinplot(x='Mental Health issue during lockdown', y='Time spent on self study', data=data, ax=ax[0,1])
sns.violinplot(x='Mental Health issue during lockdown', y='Time spent on fitness', data=data, ax=ax[1,0])
sns.violinplot(x='Mental Health issue during lockdown', y='Time spent on sleep', data=data, ax=ax[1,1])
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.set(style='white')
sns.violinplot(y='Mental Health issue during lockdown', x='Number of meals per day', data=data)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(style='ticks')
sns.countplot(y='Stress busters', data=data, order=data['Stress busters'].value_counts().index[:15], palette='Set3')
plt.xlabel("Number of Students", weight='bold')
plt.ylabel("Stress buster activity", weight='bold')
plt.show()
